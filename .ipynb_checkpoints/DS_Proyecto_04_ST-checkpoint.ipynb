# %% [markdown]
# # Proyecto 04 - Series de Tiempo
#
# ## Punto de Partida: Proyecto 3: Series de Tiempo
# **Profile: https://github.com/CristinaSacramone**
#
# **Repositorio: https://github.com/CristinaSacramone/Proyecto3Series-de-Tiempo**
#
# ### Dataset: Flujo Vehicular por Unidades de Peaje AUSA: datos de la autopista Illia, pago en Efectivo.
#
# **Recuerda descargar el dataset de [aquí](https://data.buenosaires.gob.ar/dataset/flujo-vehicular-por-unidades-peaje-ausa). Deberás descargar -  al menos para comenzar - los años 2017, 2018, 2019 y 2020.**
#
#
# ### 1. Preparación del Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import matplotlib.gridspec as gridspec
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from sklearn.metrics import mean_squared_error
import statsmodels.tsa as tsa
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
import itertools

sns.set()

# %%
data_2019 = pd.read_csv('Flujo Vehicular/flujo-vehicular-2019.csv', sep =',')
data_2018 = pd.read_csv('Flujo Vehicular/flujo-vehicular-2018.csv', sep =',')
data_2017 = pd.read_csv('Flujo Vehicular/flujo-vehicular-2017.csv',  sep =',')

# %% [markdown]
# ##### Informaciòn adicional:  Dataset Flujo Vehicular por Unidades de Peaje AUSA año 2020

# %%
data_2020 = pd.read_csv('Flujo Vehicular/flujo-vehicular-2020.csv', sep =',')

# %%
data_2020.info()
data_2020.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1847933 entries, 0 to 1847932
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   periodo         int64
#  1   fecha           object
#  2   mes             object
#  3   dia             object
#  4   dia_fecha       int64
#  5   hora_inicio     int64
#  6   hora_fin        int64
#  7   estacion        object
#  8   tipo_vehiculo   object
#  9   forma_pago      object
#  10  observacion     object
#  11  sentido         object
#  12  cantidad_pasos  int64
# dtypes: int64(5), object(8)
# memory usage: 183.3+ MB
#    periodo                fecha    mes        dia  dia_fecha  hora_inicio  \
# 0     2020  2020-01-01 00:00:00  enero  Miércoles          1            0
# 1     2020  2020-01-01 00:00:00  enero  Miércoles          1            0
# 2     2020  2020-01-01 00:00:00  enero  Miércoles          1            0
# 3     2020  2020-01-01 00:00:00  enero  Miércoles          1            0
# 4     2020  2020-01-01 00:00:00  enero  Miércoles          1            0
#
#    hora_fin estacion tipo_vehiculo forma_pago  \
# 0         1  ALBERDI          Auto   Efectivo
# 1         1  ALBERDI          Auto   Efectivo
# 2         1  ALBERDI          Auto  Rec.Deuda
# 3         1  ALBERDI          Auto  Rec.Deuda
# 4         1  ALBERDI          Auto  Rec.Deuda
#
#                         observacion    sentido  cantidad_pasos
# 0                          Efectivo     Centro              24
# 1                          Efectivo  Provincia              80
# 2                Paso en Infracción  Provincia               1
# 3  Paso en infracción con Multa LPR     Centro               1
# 4  Paso en infracción con Multa LPR  Provincia               1

# %% [markdown]
# Investiguemos que valores toman los campos **estacion, sentido, tipo_vehiculo y forma_pago**

# %%
print(data_2020['estacion'].unique())
print(data_2019['estacion'].unique())
print(data_2018['estacion'].unique())
print(data_2017['estacion'].unique())
# Out:
# ['ALBERDI' 'AVELLANEDA' 'DELLEPIANE LINIERSLEPIANE CENTRO'
#  'DELLEPIANE LINIERS' 'ILLIA' 'ILP' 'PB1' 'PB3' 'PB4' 'RETIRO' 'SALGUERO'
#  'SARMIENTO' 'PB2']
# ['Alberti' 'Avellaneda' 'Dellepiane' 'Illia' 'Retiro' 'Salguero'
#  'Sarmiento' 'PDB']
# ['Alberdi' 'Avellaneda' 'Dellepiane Centro' 'Dellepiane Liniers' 'Illia'
#  'Retiro' 'Salguero' 'Sarmiento']
# ['Alberdi' 'Avellaneda' 'Dellepiane Centro' 'Dellepiane Liniers' 'Illia'
#  'Retiro' 'Salguero' 'Sarmiento']

# %%
print(data_2020['sentido'].unique())
print(data_2019['sentido'].unique())
print(data_2018['sentido'].unique())
print(data_2017['sentido'].unique())
# Out:
# ['Centro' 'Provincia']
# ['Centro' 'Provincia']
# ['Centro' 'Provincia']
# ['Centro' 'Provincia']

# %%
print(data_2020['tipo_vehiculo'].unique())
print(data_2019['tipo_vehiculo'].unique())
print(data_2018['tipo_vehiculo'].unique())
print(data_2017['tipo_vehiculo'].unique())
# Out:
# ['Auto' 'Auto con trailer' 'Moto' 'N/D' 'Pago Doble Auto'
#  'Pago Doble Auto con trailer / Pesado 2 Ejes' 'Pago doble Moto'
#  'Pesados 2 Ejes' 'Pesados 3 Ejes' 'Pesados 4 Ejes' 'Pesados 5 Ejes'
#  'Pesados 6 Ejes']
# ['Liviano' 'Pesado']
# ['Liviano' 'Pesado']
# ['Liviano' 'Pesado']

# %%
print(data_2020['forma_pago'].unique())
print(data_2019['forma_pago'].unique())
print(data_2018['forma_pago'].unique())
print(data_2017['forma_pago'].unique())
# Out:
# ['Efectivo' 'Rec.Deuda' 'Tarjeta Magnética' 'Tag' 'Exento' 'Violación'
#  'CPP']
# ['NO COBRADO' 'TELEPASE' 'EFECTIVO' 'EXENTO' 'INFRACCION'
#  'T. DISCAPACIDAD']
# ['NO COBRADO' 'TELEPASE' 'EFECTIVO' 'EXENTO' 'TARJETA DISCAPACIDAD'
#  'INFRACCION']
# ['NO COBRADO' 'TELEPASE' 'EFECTIVO' 'TARJETA DISCAPACIDAD' 'EXENTO'
#  'INFRACCION' 'MONEDERO' 'Otros']

# %% [markdown]
# #####  Consideraciones
# 1-**TelePASE es un sistema de Telepeaje que permite pasar por los peajes sin detenerse y sin utilizar efectivo, abonando mensualmente los consumos**.
#
#                 **El sistema funciona mediante un único dispositivo llamado TAG, el mismo consiste en una oblea electrónica con un chip incorporado que se adhiere al parabrisas del vehículo.**
#
# 2-**Con respecto a los años anteriores obsevamos que hay variación en :**
#
#                                 a)Estaciones de Peaje
#                                 b)Formas de Pago
#                                 c)Tipo de Vehículos
#
# 3-**El personal de salud y el de seguridad que cumplen tareas esenciales durante la Pandemia por el COVID-19 seguirán teniendo su carril exclusivo y continuarán exentos del pago de peaje. FORMA de Pago: EXENTO**

# %% [markdown]
# ##### Podemos decir entonces que los años 2017, 2018,2019 y 2020 tienen las siguientes columnas con la siguiente información:
#
# **periodo**: año del dset
#
# **fecha**: año dia mes
#
# **hora_inicio** hora de inicio de la cuenta de vehiculos (DROP)
#
# **hora_fin** hora de fin de la cuenta de vehiculos (Vamos a usar esta para tomar la hora)
#
# **dia**: dia de la semana
#
# **estacion**: estaciones de peaje, difieren levemente entre los años (Dellepiane se unifica en 2019, antes habia Dellepiane Liniers y Centro, y se agrega PDB)
#
# **sentido**: Centro o Provincia
#
# **tipo_vehiculo**: Liviano o Pesado
#
# **forma_pago**: Hay varias y varian entre los años.
#
# **cantidad_pasos**: Cantidad de vehiculos

# %% [markdown]
# Vamos a estar trabajando con la estación **Illia** y la forma de pago **Efectivo**

# %%
#Unimos los 3 datasets, podemos hacerlo asi directamente ya que tienen las mismas columnas
dataset = pd.concat([data_2019, data_2018, data_2017])
#Nos quedamos solamente con la estación Illia y la forma de pago Efectivo
mask = np.logical_and(dataset.estacion=='Illia', dataset.forma_pago == 'EFECTIVO')
dataset = dataset[mask]
#Quitamos las columnas que no vamos a utilizar
dataset.drop(columns = ['periodo','hora_inicio','forma_pago', 'estacion'], inplace = True)
#Pasamos la columna fecha a formato datetime, y le unimos la hora_fin como hora
dataset['fecha2'] = pd.to_datetime(dataset.fecha) + pd.to_timedelta(dataset.hora_fin, unit = 'h')
#Quitamos las columnas fecha y hora_fin ya que las incluimos en el campo fecha2
dataset.drop(columns=['fecha','hora_fin'], inplace = True)
#Corregimos el nombre de fecha2 a fecha
dataset.rename(columns = {'fecha2':'fecha'}, inplace = True) 
#Reordenamos el dataset por fecha
dataset.sort_values('fecha', inplace = True)
dataset.reset_index(drop=True, inplace = True)
dataset
# Out:
#             dia    sentido tipo_vehiculo  cantidad_pasos               fecha
# 0       Domingo  Provincia        Pesado               1 2017-01-01 00:00:00
# 1       Domingo  Provincia       Liviano               9 2017-01-01 00:00:00
# 2       Domingo  Provincia       Liviano             644 2017-01-01 00:00:00
# 3       Domingo  Provincia        Pesado               6 2017-01-01 00:00:00
# 4       Domingo  Provincia        Pesado               1 2017-01-01 00:00:00
# ...         ...        ...           ...             ...                 ...
# 238864   Martes  Provincia       Liviano             556 2019-12-31 22:00:00
# 238865   Martes  Provincia        Pesado               1 2019-12-31 22:00:00
# 238866   Martes     Centro       Liviano             580 2019-12-31 22:00:00
# 238867   Martes     Centro       Liviano             214 2019-12-31 23:00:00
# 238868   Martes  Provincia       Liviano             190 2019-12-31 23:00:00
#
# [238869 rows x 5 columns]

# %%
#Graficamos nuestros datos, tal como están
plt.figure(figsize = (15,6))
plt.plot(dataset.fecha, dataset.cantidad_pasos,color='red')
plt.title("Flujo de pasos medido por Hora \n", color= 'blue', fontsize= 20)
plt.xlabel('Tiempo', color='green')
plt.ylabel('Cantidad de pasos, por hora', color='green')
plt.show()

# %%
#Resampleamos nuestros datos para agrupar por dia, y asi tal vez lograr una visualización mas amigable
diario = dataset.resample('D', on = 'fecha').sum()

# %%
plt.figure(figsize = (15,6))
plt.plot(diario.index, diario.cantidad_pasos,color='green')
plt.title("Flujo de pasos medido por dia \n", color= 'blue', fontsize= 20)
plt.xlabel('Tiempo', color='red')
plt.ylabel('Cantidad de pasos, por dia',color='red' )
plt.show()

# %% [markdown]
# ##### Observaciones:
#     1-Cómo veníamos trabajando en el Proyecto 3 con estos datos, tenemos la certeza de que no hay valores faltantes.
#     2-En cuanto a los valores atípicos (picos negativos), reemplazaremos los valores atípicos mediante  la interpolación.

# %%
#Se detectan los valores atipicos
diario.cantidad_pasos[diario.cantidad_pasos <=10000] = np.nan
print(diario.isna().sum())
# Se realiza la interpolacion.
diario = diario.interpolate(method='nearest', k=4)
print(diario.isna().sum())
# Out:
# cantidad_pasos    6
# dtype: int64
# cantidad_pasos    0
# dtype: int64

# %%
plt.figure(figsize = (15,6))
plt.plot(diario.index, diario.cantidad_pasos,color='green')
plt.title("Flujo de pasos medido por dia \n sin valores atípicos", color= 'blue', fontsize= 20)
plt.xlabel('Tiempo', color='red')
plt.ylabel('Cantidad de pasos, por dia',color='red' )
plt.ylim(ymin=0)
plt.show()

# %% [markdown]
# ##### Observaciones:
#     1-Cómo veníamos trabajando en el Proyecto 3 con estos datos, tenemos la certeza de que no hay valores faltantes.
#     2-En cuanto a los valores atípicos (picos negativos), reemplazaremos los valores atípicos mediante  la interpolación.

# %%
# Trabajaremos al igual que en el Proyecto 3 con la media semanal y con semanas enteras
semanal_m =diario.resample('W').mean()#Resampleamos a Semanal Media
semanal_m=semanal_m[(semanal_m.index >='2017-01-08')&(semanal_m.index <='2019-12-29')]#Trabajaremos con semnas enteras
print(semanal_m.shape)
semanal_m
# Out:
# (156, 1)
#             cantidad_pasos
# fecha
# 2017-01-08    49601.714286
# 2017-01-15    52344.714286
# 2017-01-22    51030.714286
# 2017-01-29    50654.428571
# 2017-02-05    51343.000000
# ...                    ...
# 2019-12-01    38079.285714
# 2019-12-08    40413.000000
# 2019-12-15    38994.285714
# 2019-12-22    41840.142857
# 2019-12-29    32341.428571
#
# [156 rows x 1 columns]

# %% [markdown]
# ## Analizando 2020

# %%
#Sobre la estacion Illia
dataset_2020 =data_2020[data_2020.estacion=='ILLIA']
dataset_2020.describe(include='all')
# Out:
#          periodo                fecha     mes        dia      dia_fecha  \
# count   215490.0               215490  215490     215490  215490.000000
# unique       NaN                  274       9          7            NaN
# top          NaN  2020-02-21 00:00:00   enero  Miércoles            NaN
# freq         NaN                 1212   31057      34244            NaN
# mean      2020.0                  NaN     NaN        NaN      15.606307
# std          0.0                  NaN     NaN        NaN       8.770295
# min       2020.0                  NaN     NaN        NaN       1.000000
# 25%       2020.0                  NaN     NaN        NaN       8.000000
# 50%       2020.0                  NaN     NaN        NaN      16.000000
# 75%       2020.0                  NaN     NaN        NaN      23.000000
# max       2020.0                  NaN     NaN        NaN      31.000000
#
#           hora_inicio       hora_fin estacion tipo_vehiculo forma_pago  \
# count   215490.000000  215490.000000   215490        215490     215490
# unique            NaN            NaN        1            12          7
# top               NaN            NaN    ILLIA          Auto        Tag
# freq              NaN            NaN   215490         96220      98368
# mean        12.145858      12.397202      NaN           NaN        NaN
# std          6.230917       6.322939      NaN           NaN        NaN
# min          0.000000       0.000000      NaN           NaN        NaN
# 25%          7.000000       8.000000      NaN           NaN        NaN
# 50%         12.000000      13.000000      NaN           NaN        NaN
# 75%         17.000000      18.000000      NaN           NaN        NaN
# max         23.000000      23.000000      NaN           NaN        NaN
#
#           observacion sentido  cantidad_pasos
# count          215490  215490   215490.000000
# unique             20       2             NaN
# top     Tag - PosPago  Centro             NaN
# freq            47502  111629             NaN
# mean              NaN     NaN       58.485948
# std               NaN     NaN      182.367450
# min               NaN     NaN        1.000000
# 25%               NaN     NaN        1.000000
# 50%               NaN     NaN        4.000000
# 75%               NaN     NaN       20.000000
# max               NaN     NaN     3234.000000

# %%
#Sobre la estacion Illia
dataset_2020['forma_pago'].value_counts()
# Out:
# Tag                  98368
# Efectivo             39072
# Violación            27524
# Rec.Deuda            21803
# Exento               18098
# Tarjeta Magnética     7712
# CPP                   2913
# Name: forma_pago, dtype: int64

# %%
# de todas las estaciones
data_2020['forma_pago'].value_counts()
# Out:
# Tag                  1045096
# Violación             312230
# Efectivo              196304
# Rec.Deuda             130578
# Exento                110340
# Tarjeta Magnética      36006
# CPP                    17379
# Name: forma_pago, dtype: int64

# %% [markdown]
# **Al comparar las formas de pago en el año 2020, vemos que  la forma de pago en EFECTIVO disminuyó drásticamente y que la mayoría de los usuarios optaron  por la forma de pago con Tag (TELEPASE)**
#
# **Esto, como comenté en el proyecto anterior se debe a las polìticas aplicadas en las autopistas por AUSA de descuentos de hasta 20% por pago con Telepase. A partir del 28/09/2020 el uso de Telepase es Obligatorio en las Autopistas que dependen de AUSA, siendo el costo del peaje un 55% menor que si se abona en Efectivo**

# %%
d_2020=data_2020[(data_2020.estacion=='ILLIA')& (data_2020.forma_pago == 'Efectivo')]
d_2020
# Out:
#          periodo                fecha         mes        dia  dia_fecha  \
# 52          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 53          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 134         2020  2020-01-01 00:00:00       enero  Miércoles          1
# 135         2020  2020-01-01 00:00:00       enero  Miércoles          1
# 202         2020  2020-01-01 00:00:00       enero  Miércoles          1
# ...          ...                  ...         ...        ...        ...
# 1847017     2020           2020-09-29  septiembre     Martes         29
# 1847412     2020           2020-09-30  septiembre  Miércoles         30
# 1847475     2020           2020-09-30  septiembre  Miércoles         30
# 1847506     2020           2020-09-30  septiembre  Miércoles         30
# 1847541     2020           2020-09-30  septiembre  Miércoles         30
#
#          hora_inicio  hora_fin estacion   tipo_vehiculo forma_pago  \
# 52                 0         1    ILLIA            Auto   Efectivo
# 53                 0         1    ILLIA            Auto   Efectivo
# 134                1         2    ILLIA            Auto   Efectivo
# 135                1         2    ILLIA            Auto   Efectivo
# 202                2         3    ILLIA            Auto   Efectivo
# ...              ...       ...      ...             ...        ...
# 1847017           15        16    ILLIA  Pesados 6 Ejes   Efectivo
# 1847412            8         9    ILLIA  Pesados 6 Ejes   Efectivo
# 1847475           10        11    ILLIA  Pesados 6 Ejes   Efectivo
# 1847506           11        12    ILLIA  Pesados 6 Ejes   Efectivo
# 1847541           12        13    ILLIA  Pesados 6 Ejes   Efectivo
#
#         observacion    sentido  cantidad_pasos
# 52         Efectivo     Centro             326
# 53         Efectivo  Provincia             319
# 134        Efectivo     Centro             199
# 135        Efectivo  Provincia             180
# 202        Efectivo     Centro             114
# ...             ...        ...             ...
# 1847017    Efectivo  Provincia               1
# 1847412    Efectivo  Provincia               1
# 1847475    Efectivo     Centro               1
# 1847506    Efectivo  Provincia               2
# 1847541    Efectivo  Provincia               1
#
# [39072 rows x 13 columns]

# %%
#Quitamos las columnas que no vamos a utilizar
d_2020.drop(columns = ['periodo','hora_inicio','forma_pago', 'estacion'], inplace = True)
#Pasamos la columna fecha a formato datetime, y le unimos la hora_fin como hora
d_2020['fecha2'] = pd.to_datetime(d_2020.fecha) + pd.to_timedelta(d_2020.hora_fin, unit = 'h')
#Quitamos las columnas fecha y hora_fin ya que las incluimos en el campo fecha2
d_2020.drop(columns=['fecha','hora_fin','dia_fecha'], inplace = True)
#Corregimos el nombre de fecha2 a fecha
d_2020.rename(columns = {'fecha2':'fecha'}, inplace = True) 
#Reordenamos el d_2020 por fecha
d_2020.sort_values('fecha', inplace = True)
d_2020.reset_index(drop=True, inplace = True)
#Resampleamos nuestros datos para agrupar por dia, y asi tal vez lograr una visualización mas amigable
da_2020 = d_2020.resample('D', on = 'fecha').sum()
da_2020
# Out:
#             cantidad_pasos
# fecha
# 2020-01-01           21395
# 2020-01-02           33722
# 2020-01-03           37067
# 2020-01-04           30627
# 2020-01-05           27812
# ...                    ...
# 2020-09-26            5474
# 2020-09-27            3987
# 2020-09-28            5379
# 2020-09-29            5369
# 2020-09-30            5432
#
# [274 rows x 1 columns]

# %% [markdown]
# **Inspeccionando si hay valores faltantes**

# %%
da_2020.isnull (). sum ()
# Out:
# cantidad_pasos    0
# dtype: int64

# %% [markdown]
# *No hay valores faltantes*

# %% [markdown]
# ### Analizando  las formas de pago: Efectivo y Telepase

# %% [markdown]
# #### 1-En la  Autopista ILLIA las diferentes formas de pago evaluadas (Efectivo y Telepase): antes y durante la cuarentena

# %%
#Forma de Pago Efectivo
# Al igual que con los datos anteriores, trabajamos con semanal media
semanal_20_m =da_2020.resample('W').mean()
print(semanal_20_m.shape)
semanal_20_m
# Out:
# (40, 1)
#             cantidad_pasos
# fecha
# 2020-01-05    30124.600000
# 2020-01-12    34765.571429
# 2020-01-19    35259.714286
# 2020-01-26    34456.000000
# 2020-02-02    36190.714286
# 2020-02-09    35306.428571
# 2020-02-16    37351.142857
# 2020-02-23    36728.000000
# 2020-03-01    33641.000000
# 2020-03-08    36415.714286
# 2020-03-15    31827.571429
# 2020-03-22    15407.857143
# 2020-03-29        0.000000
# 2020-04-05        0.000000
# 2020-04-12        0.000000
# 2020-04-19        0.000000
# 2020-04-26        0.000000
# 2020-05-03        0.000000
# 2020-05-10        0.000000
# 2020-05-17        0.142857
# 2020-05-24     7269.000000
# 2020-05-31     7844.857143
# 2020-06-07    10070.428571
# 2020-06-14    10921.714286
# 2020-06-21    10246.714286
# 2020-06-28    11610.714286
# 2020-07-05    10534.142857
# 2020-07-12     8683.285714
# 2020-07-19    11207.000000
# 2020-07-26    12086.428571
# 2020-08-02    13204.142857
# 2020-08-09    13364.714286
# 2020-08-16    13417.285714
# 2020-08-23    11678.000000
# 2020-08-30    11842.571429
# 2020-09-06    11058.428571
# 2020-09-13    11162.428571
# 2020-09-20     9964.142857
# 2020-09-27     8741.571429
# 2020-10-04     5393.333333

# %% [markdown]
# * Creando el dataset de Telepase (Tag)

# %%
d_2020_t=data_2020[(data_2020.estacion=='ILLIA')& (data_2020.forma_pago == 'Tag')]
d_2020_t
# Out:
#          periodo                fecha         mes        dia  dia_fecha  \
# 62          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 63          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 64          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 65          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 66          2020  2020-01-01 00:00:00       enero  Miércoles          1
# ...          ...                  ...         ...        ...        ...
# 1847639     2020           2020-09-30  septiembre  Miércoles         30
# 1847671     2020           2020-09-30  septiembre  Miércoles         30
# 1847672     2020           2020-09-30  septiembre  Miércoles         30
# 1847703     2020           2020-09-30  septiembre  Miércoles         30
# 1847732     2020           2020-09-30  septiembre  Miércoles         30
#
#          hora_inicio  hora_fin estacion   tipo_vehiculo forma_pago  \
# 62                 0         1    ILLIA            Auto        Tag
# 63                 0         1    ILLIA            Auto        Tag
# 64                 0         1    ILLIA            Auto        Tag
# 65                 0         1    ILLIA            Auto        Tag
# 66                 0         1    ILLIA            Auto        Tag
# ...              ...       ...      ...             ...        ...
# 1847639           15        16    ILLIA  Pesados 6 Ejes        Tag
# 1847671           16        17    ILLIA  Pesados 6 Ejes        Tag
# 1847672           16        17    ILLIA  Pesados 6 Ejes        Tag
# 1847703           17        18    ILLIA  Pesados 6 Ejes        Tag
# 1847732           18        19    ILLIA  Pesados 6 Ejes        Tag
#
#                observacion    sentido  cantidad_pasos
# 62           Tag - PosPago     Centro             205
# 63           Tag - PosPago  Provincia             141
# 64       Tag - PosPago OCR     Centro              22
# 65       Tag - PosPago OCR  Provincia             131
# 66           Tag - PrePago     Centro               8
# ...                    ...        ...             ...
# 1847639      Tag - PosPago  Provincia               2
# 1847671      Tag - PosPago     Centro               2
# 1847672  Tag - PosPago OCR     Centro               1
# 1847703      Tag - PosPago     Centro               2
# 1847732      Tag - PosPago  Provincia               1
#
# [98368 rows x 13 columns]

# %%
#Quitamos las columnas que no vamos a utilizar
d_2020_t.drop(columns = ['periodo','hora_inicio','forma_pago', 'estacion'], inplace = True)
#Pasamos la columna fecha a formato datetime, y le unimos la hora_fin como hora
d_2020_t['fecha2'] = pd.to_datetime(d_2020_t.fecha) + pd.to_timedelta(d_2020_t.hora_fin, unit = 'h')
#Quitamos las columnas fecha y hora_fin ya que las incluimos en el campo fecha2
d_2020_t.drop(columns=['fecha','hora_fin','dia_fecha'], inplace = True)
#Corregimos el nombre de fecha2 a fecha
d_2020_t.rename(columns = {'fecha2':'fecha'}, inplace = True) 
#Reordenamos el d_2020_t por fecha
d_2020_t.sort_values('fecha', inplace = True)
d_2020_t.reset_index(drop=True, inplace = True)
#Resampleamos nuestros datos para agrupar por dia, y asi tal vez lograr una visualización mas amigable
da_2020_t = d_2020_t.resample('D', on = 'fecha').sum()
semanal_20_t =da_2020_t.resample('W').mean()
print(semanal_20_t.shape)
semanal_20_t
# Out:
# (40, 1)
#             cantidad_pasos
# fecha
# 2020-01-05    33239.600000
# 2020-01-12    45275.714286
# 2020-01-19    46034.857143
# 2020-01-26    45056.285714
# 2020-02-02    47610.142857
# 2020-02-09    48739.000000
# 2020-02-16    50148.142857
# 2020-02-23    50353.714286
# 2020-03-01    42120.142857
# 2020-03-08    54410.142857
# 2020-03-15    50522.285714
# 2020-03-22    26374.142857
# 2020-03-29     3002.857143
# 2020-04-05     4008.285714
# 2020-04-12     5819.428571
# 2020-04-19     8204.000000
# 2020-04-26     9615.285714
# 2020-05-03    10619.428571
# 2020-05-10    13500.285714
# 2020-05-17    15191.000000
# 2020-05-24    12152.571429
# 2020-05-31    11073.428571
# 2020-06-07    14476.142857
# 2020-06-14    15771.142857
# 2020-06-21    14853.857143
# 2020-06-28    17204.857143
# 2020-07-05    14711.857143
# 2020-07-12    12144.857143
# 2020-07-19    16073.428571
# 2020-07-26    17789.714286
# 2020-08-02    19161.571429
# 2020-08-09    19701.714286
# 2020-08-16    21865.000000
# 2020-08-23    21419.428571
# 2020-08-30    25374.285714
# 2020-09-06    27266.000000
# 2020-09-13    28575.571429
# 2020-09-20    30614.571429
# 2020-09-27    32279.571429
# 2020-10-04    41478.000000

# %%
# VIsualizacion de las tendencias 
plt.figure(figsize=(15,5))
plt.plot(semanal_20_m.index, semanal_20_m.cantidad_pasos,lw=3,color='green', label='Pago en Efectivo')
plt.plot(semanal_20_t.index, semanal_20_t.cantidad_pasos, lw=3, color='magenta',label='Pago con TELEPASE (Tag)')
plt.title ('Año 2020:Autopista Illia: EFECTIVO & TELEPASE', color='red', fontsize=30)
plt.xlabel('\n Fecha', color='blue',fontsize=14)
plt.ylabel('Cantidad de pasos', color='blue',fontsize=14)

plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Conclusiones
#         1-Producto de la cuarentena que decretaron en la República Argentina a partir del 20/03/2020 los Pasos de vehículo
#         con pago en efectivo se igualaron a cero hasta el 17/05/2020 que se fueron habilitando algunas actividades.
#         2-Algunas actividades fueron habilitadas a trabajar con permisos especiales, para mantener el abastecimiento y caos
#         del pais durante la cuarentena
#         3-Dadas las politicas implementadas por el Gobierno de la Ciudad y AUSA, fue estimulada la forma de pago con
#         telepase (Tag), ya sea como forma de prevenir el contacto entre personas, y como forma mas rápida de pase

# %% [markdown]
# #### 2-Comparamos Estacion Illia con Avellaneda: las dos formas de pago

# %% [markdown]
# * Creando el dataset de AVELLANEDA forma de pago Efectivo

# %%
d_2020_a=data_2020[(data_2020.estacion=='AVELLANEDA')& (data_2020.forma_pago == 'Efectivo')]
d_2020_a
# Out:
#          periodo                fecha         mes        dia  dia_fecha  \
# 11          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 12          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 100         2020  2020-01-01 00:00:00       enero  Miércoles          1
# 101         2020  2020-01-01 00:00:00       enero  Miércoles          1
# 170         2020  2020-01-01 00:00:00       enero  Miércoles          1
# ...          ...                  ...         ...        ...        ...
# 1847432     2020           2020-09-30  septiembre  Miércoles         30
# 1847531     2020           2020-09-30  septiembre  Miércoles         30
# 1847562     2020           2020-09-30  septiembre  Miércoles         30
# 1847593     2020           2020-09-30  septiembre  Miércoles         30
# 1847850     2020           2020-09-30  septiembre  Miércoles         30
#
#          hora_inicio  hora_fin    estacion   tipo_vehiculo forma_pago  \
# 11                 0         1  AVELLANEDA            Auto   Efectivo
# 12                 0         1  AVELLANEDA            Auto   Efectivo
# 100                1         2  AVELLANEDA            Auto   Efectivo
# 101                1         2  AVELLANEDA            Auto   Efectivo
# 170                2         3  AVELLANEDA            Auto   Efectivo
# ...              ...       ...         ...             ...        ...
# 1847432            9        10  AVELLANEDA  Pesados 6 Ejes   Efectivo
# 1847531           12        13  AVELLANEDA  Pesados 6 Ejes   Efectivo
# 1847562           13        14  AVELLANEDA  Pesados 6 Ejes   Efectivo
# 1847593           14        15  AVELLANEDA  Pesados 6 Ejes   Efectivo
# 1847850           23         0  AVELLANEDA  Pesados 6 Ejes   Efectivo
#
#         observacion    sentido  cantidad_pasos
# 11         Efectivo     Centro             542
# 12         Efectivo  Provincia             596
# 100        Efectivo     Centro             255
# 101        Efectivo  Provincia             373
# 170        Efectivo     Centro             128
# ...             ...        ...             ...
# 1847432    Efectivo  Provincia               1
# 1847531    Efectivo  Provincia               1
# 1847562    Efectivo     Centro               1
# 1847593    Efectivo  Provincia               1
# 1847850    Efectivo     Centro               1
#
# [63713 rows x 13 columns]

# %%
#Quitamos las columnas que no vamos a utilizar
d_2020_a.drop(columns = ['periodo','hora_inicio','forma_pago', 'estacion'], inplace = True)
#Pasamos la columna fecha a formato datetime, y le unimos la hora_fin como hora
d_2020_a['fecha2'] = pd.to_datetime(d_2020_a.fecha) + pd.to_timedelta(d_2020_a.hora_fin, unit = 'h')
#Quitamos las columnas fecha y hora_fin ya que las incluimos en el campo fecha2
d_2020_a.drop(columns=['fecha','hora_fin','dia_fecha'], inplace = True)
#Corregimos el nombre de fecha2 a fecha
d_2020_a.rename(columns = {'fecha2':'fecha'}, inplace = True) 
#Reordenamos el d_2020_a por fecha
d_2020_a.sort_values('fecha', inplace = True)
d_2020_a.reset_index(drop=True, inplace = True)
#Resampleamos nuestros datos para agrupar por dia, y asi tal vez lograr una visualización mas amigable
da_2020_a = d_2020_a.resample('D', on = 'fecha').sum()
semanal_20_a =da_2020_a.resample('W').mean()
print(semanal_20_a.shape)
semanal_20_a
# Out:
# (40, 1)
#             cantidad_pasos
# fecha
# 2020-01-05    52176.400000
# 2020-01-12    57942.285714
# 2020-01-19    58302.714286
# 2020-01-26    57321.285714
# 2020-02-02    58811.285714
# 2020-02-09    58217.142857
# 2020-02-16    61756.714286
# 2020-02-23    60179.428571
# 2020-03-01    55185.428571
# 2020-03-08    59999.142857
# 2020-03-15    52970.142857
# 2020-03-22    27959.000000
# 2020-03-29        0.000000
# 2020-04-05        0.000000
# 2020-04-12        0.000000
# 2020-04-19        0.000000
# 2020-04-26        0.000000
# 2020-05-03        0.000000
# 2020-05-10        0.000000
# 2020-05-17        0.000000
# 2020-05-24    17792.285714
# 2020-05-31    18249.428571
# 2020-06-07    22719.571429
# 2020-06-14    24413.000000
# 2020-06-21    22699.571429
# 2020-06-28    25536.571429
# 2020-07-05    21765.857143
# 2020-07-12    19697.000000
# 2020-07-19    25270.142857
# 2020-07-26    27099.285714
# 2020-08-02    28482.571429
# 2020-08-09    28251.428571
# 2020-08-16    28660.000000
# 2020-08-23    24918.857143
# 2020-08-30    24849.571429
# 2020-09-06    23337.857143
# 2020-09-13    22828.428571
# 2020-09-20    21189.714286
# 2020-09-27    18440.000000
# 2020-10-04    10485.666667

# %% [markdown]
# * Creando el dataset de AVELLANEDA forma de pago Telepase (Tag)

# %%
d_2020_at=data_2020[(data_2020.estacion=='AVELLANEDA')& (data_2020.forma_pago == 'Tag')]
d_2020_at
# Out:
#          periodo                fecha         mes        dia  dia_fecha  \
# 21          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 22          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 23          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 24          2020  2020-01-01 00:00:00       enero  Miércoles          1
# 25          2020  2020-01-01 00:00:00       enero  Miércoles          1
# ...          ...                  ...         ...        ...        ...
# 1847831     2020           2020-09-30  septiembre  Miércoles         30
# 1847851     2020           2020-09-30  septiembre  Miércoles         30
# 1847852     2020           2020-09-30  septiembre  Miércoles         30
# 1847853     2020           2020-09-30  septiembre  Miércoles         30
# 1847854     2020           2020-09-30  septiembre  Miércoles         30
#
#          hora_inicio  hora_fin    estacion   tipo_vehiculo forma_pago  \
# 21                 0         1  AVELLANEDA            Auto        Tag
# 22                 0         1  AVELLANEDA            Auto        Tag
# 23                 0         1  AVELLANEDA            Auto        Tag
# 24                 0         1  AVELLANEDA            Auto        Tag
# 25                 0         1  AVELLANEDA            Auto        Tag
# ...              ...       ...         ...             ...        ...
# 1847831           22        23  AVELLANEDA  Pesados 6 Ejes        Tag
# 1847851           23         0  AVELLANEDA  Pesados 6 Ejes        Tag
# 1847852           23         0  AVELLANEDA  Pesados 6 Ejes        Tag
# 1847853           23         0  AVELLANEDA  Pesados 6 Ejes        Tag
# 1847854           23         0  AVELLANEDA  Pesados 6 Ejes        Tag
#
#                observacion    sentido  cantidad_pasos
# 21           Tag - PosPago     Centro             361
# 22           Tag - PosPago  Provincia             248
# 23       Tag - PosPago OCR     Centro              55
# 24       Tag - PosPago OCR  Provincia             194
# 25           Tag - PrePago     Centro               8
# ...                    ...        ...             ...
# 1847831  Tag - PosPago OCR  Provincia               1
# 1847851      Tag - PosPago     Centro              14
# 1847852      Tag - PosPago  Provincia              14
# 1847853  Tag - PosPago OCR     Centro               2
# 1847854  Tag - PosPago OCR  Provincia               1
#
# [197013 rows x 13 columns]

# %%
#Quitamos las columnas que no vamos a utilizar
d_2020_at.drop(columns = ['periodo','hora_inicio','forma_pago', 'estacion'], inplace = True)
#Pasamos la columna fecha a formato datetime, y le unimos la hora_fin como hora
d_2020_at['fecha2'] = pd.to_datetime(d_2020_at.fecha) + pd.to_timedelta(d_2020_at.hora_fin, unit = 'h')
#Quitamos las columnas fecha y hora_fin ya que las incluimos en el campo fecha2
d_2020_at.drop(columns=['fecha','hora_fin','dia_fecha'], inplace = True)
#Corregimos el nombre de fecha2 a fecha
d_2020_at.rename(columns = {'fecha2':'fecha'}, inplace = True) 
#Reordenamos el d_2020_at por fecha
d_2020_at.sort_values('fecha', inplace = True)
d_2020_at.reset_index(drop=True, inplace = True)
#Resampleamos nuestros datos para agrupar por dia, y asi tal vez lograr una visualización mas amigable
da_2020_at = d_2020_at.resample('D', on = 'fecha').sum()
semanal_20_at =da_2020_at.resample('W').mean()
print(semanal_20_at.shape)
semanal_20_at
# Out:
# (40, 1)
#             cantidad_pasos
# fecha
# 2020-01-05    50648.200000
# 2020-01-12    63220.571429
# 2020-01-19    63689.000000
# 2020-01-26    63745.142857
# 2020-02-02    65039.285714
# 2020-02-09    65366.571429
# 2020-02-16    67030.714286
# 2020-02-23    66352.714286
# 2020-03-01    57778.714286
# 2020-03-08    70296.000000
# 2020-03-15    66362.000000
# 2020-03-22    40547.714286
# 2020-03-29     9393.142857
# 2020-04-05    10929.000000
# 2020-04-12    11745.857143
# 2020-04-19    17477.857143
# 2020-04-26    17416.714286
# 2020-05-03    15874.000000
# 2020-05-10    25391.142857
# 2020-05-17    28221.714286
# 2020-05-24    23351.714286
# 2020-05-31    21553.285714
# 2020-06-07    26300.000000
# 2020-06-14    27698.000000
# 2020-06-21    25555.285714
# 2020-06-28    29289.000000
# 2020-07-05    25191.571429
# 2020-07-12    21646.000000
# 2020-07-19    29002.142857
# 2020-07-26    31348.285714
# 2020-08-02    32215.428571
# 2020-08-09    32851.285714
# 2020-08-16    36832.142857
# 2020-08-23    36202.857143
# 2020-08-30    43745.857143
# 2020-09-06    46410.142857
# 2020-09-13    50304.285714
# 2020-09-20    55449.571429
# 2020-09-27    57572.142857
# 2020-10-04    73773.000000

# %%
# VIsualizacion de las tendencias 
plt.figure(figsize=(15,5))
plt.plot(semanal_20_t.index, semanal_20_t.cantidad_pasos,lw=3,color='green', label='Illia-Telepase')
plt.plot(semanal_20_at.index, semanal_20_at.cantidad_pasos, lw=3, color='indigo',label='Avellaneda-Telepase')
plt.plot(semanal_20_m.index, semanal_20_m.cantidad_pasos,lw=3,color='orange', label='Illia-Efectivo')
plt.plot(semanal_20_a.index, semanal_20_a.cantidad_pasos, lw=3, color='magenta',label='Avellaneda-Efectivo')


plt.title ('AÑO 2020: Estación Illia vs Avellaneda', color='red', fontsize=30)
plt.xlabel('\n Fecha', color='blue',fontsize=14)
plt.ylabel('Cantidad de pasos', color='blue',fontsize=14)

plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Claramente observamos que en las estaciones de Peaje,  el comportamiento fue similar; decrecimiento de pago en Efectivo, con el concomitante aumento de pago  con Telepase (Tag)

# %% [markdown]
# ## Concatenamos todos los dataset

# %%
diario_2020= pd.concat([diario, da_2020])
diario_2020
# Out:
#             cantidad_pasos
# fecha
# 2017-01-01         31183.0
# 2017-01-02         51568.0
# 2017-01-03         51093.0
# 2017-01-04         53332.0
# 2017-01-05         56486.0
# ...                    ...
# 2020-09-26          5474.0
# 2020-09-27          3987.0
# 2020-09-28          5379.0
# 2020-09-29          5369.0
# 2020-09-30          5432.0
#
# [1369 rows x 1 columns]

# %%
plt.figure(figsize = (15,6))
plt.plot(diario_2020.index, diario_2020.cantidad_pasos,color='green')
plt.title("Cantidad de Pases diarios", color= 'blue', fontsize= 20)
plt.xlabel('Tiempo')
plt.ylabel('Cantidad de pases, por dia ',color='red' )
plt.show()

# %% [markdown]
# ##### Visualización de lo ya expuesto:
#     1- Pases con forma de pago en efectivo igual a 0 (cero) durante las semanas del 21/03/2020, que se estableció el ASPO (Aislamiento Social Preventivo Obligatorio) y la habilitación de algunas actividades.
#     2- Migración hacia la forma de pago con telepase

# %%
semanal_m_20 =diario_2020.resample('W').mean()
print(semanal_m_20.shape)
semanal_m_20
# Out:
# (197, 1)
#             cantidad_pasos
# fecha
# 2017-01-01    31183.000000
# 2017-01-08    49601.714286
# 2017-01-15    52344.714286
# 2017-01-22    51030.714286
# 2017-01-29    50654.428571
# ...                    ...
# 2020-09-06    11058.428571
# 2020-09-13    11162.428571
# 2020-09-20     9964.142857
# 2020-09-27     8741.571429
# 2020-10-04     5393.333333
#
# [197 rows x 1 columns]

# %%
#Tomamos siempre semanas completas
semanal_m_20=semanal_m_20[(semanal_m_20.index >='2017-01-08')&(semanal_m_20.index <='2020-09-27')]
semanal_m_20
# Out:
#             cantidad_pasos
# fecha
# 2017-01-08    49601.714286
# 2017-01-15    52344.714286
# 2017-01-22    51030.714286
# 2017-01-29    50654.428571
# 2017-02-05    51343.000000
# ...                    ...
# 2020-08-30    11842.571429
# 2020-09-06    11058.428571
# 2020-09-13    11162.428571
# 2020-09-20     9964.142857
# 2020-09-27     8741.571429
#
# [195 rows x 1 columns]

# %% [markdown]
# ## Arima

# %% [markdown]
# ###### La métrica de Evaluacion elegida es RMSE dado el manejo de los valores atípicos que se ha realizado en el preprocesamiento de datos

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# **En el Proyecto 3: SARIMAX One-Step fue el modelo elegido para predecir el 2020**
#
# *Uno de los métodos más comunes utilizados en la predicción de series de tiempo se conoce como el modelo ARIMA, que significa A utoreg R essive I ntegrado M oving A verage. ARIMA es un modelo que se puede ajustar a datos de series de tiempo para comprender o predecir mejor los puntos futuros de la serie.*

# %%
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# * Uno de los métodos disponibles en Python para modelar y predecir puntos futuros de una serie de tiempo se conoce como SARIMAX , que significa promedios móviles integrados autorregresivos estacionales con regresores eXógenos .

# %%
import itertools
warnings.filterwarnings('ignore')

# %%
semanal_m=semanal_m[(semanal_m.index >='2017-01-08')&(semanal_m.index <='2019-12-29')]
y=semanal_m
y
# Out:
#             cantidad_pasos
# fecha
# 2017-01-08    49601.714286
# 2017-01-15    52344.714286
# 2017-01-22    51030.714286
# 2017-01-29    50654.428571
# 2017-02-05    51343.000000
# ...                    ...
# 2019-12-01    38079.285714
# 2019-12-08    40413.000000
# 2019-12-15    38994.285714
# 2019-12-22    41840.142857
# 2019-12-29    32341.428571
#
# [156 rows x 1 columns]

# %%
semanal_2020_m=semanal_20_m[(semanal_20_m.index >='2020-01-05')&(semanal_20_m.index <='2020-03-15')]
y_2020=semanal_2020_m
y_2020
# Out:
#             cantidad_pasos
# fecha
# 2020-01-05    30124.600000
# 2020-01-12    34765.571429
# 2020-01-19    35259.714286
# 2020-01-26    34456.000000
# 2020-02-02    36190.714286
# 2020-02-09    35306.428571
# 2020-02-16    37351.142857
# 2020-02-23    36728.000000
# 2020-03-01    33641.000000
# 2020-03-08    36415.714286
# 2020-03-15    31827.571429

# %%
y_2020['2020':]
# Out:
#             cantidad_pasos
# fecha
# 2020-01-05    30124.600000
# 2020-01-12    34765.571429
# 2020-01-19    35259.714286
# 2020-01-26    34456.000000
# 2020-02-02    36190.714286
# 2020-02-09    35306.428571
# 2020-02-16    37351.142857
# 2020-02-23    36728.000000
# 2020-03-01    33641.000000
# 2020-03-08    36415.714286
# 2020-03-15    31827.571429

# %% [markdown]
# * _*Del Año 2020 hasta el 20/03/2020, ya que ahi comienza la cuarentena**.*_

# %%
d=range(0,3)
p=q=range(8,13)
pdq=list(itertools.product (p,d,q))
seasonal_pdq=[(x[0],x[1],x[2],12)
              for x in list(itertools.product (p,d,q)) ]
print('Ejemplos de combinaciones de parametros para SARIMAX ....')
print('SARIMAX:{} x{}'.format(pdq[1],seasonal_pdq[1]))
print('SARIMAX:{} x{}'.format(pdq[1],seasonal_pdq[2]))
print('SARIMAX:{} x{}'.format(pdq[2],seasonal_pdq[3]))
print('SARIMAX:{} x{}'.format(pdq[2],seasonal_pdq[4]))
# Out:
# Ejemplos de combinaciones de parametros para SARIMAX ....
# SARIMAX:(8, 0, 9) x(8, 0, 9, 12)
# SARIMAX:(8, 0, 9) x(8, 0, 10, 12)
# SARIMAX:(8, 0, 10) x(8, 0, 11, 12)
# SARIMAX:(8, 0, 10) x(8, 0, 12, 12)

# %%
y= semanal_m.cantidad_pasos
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(10, 1, 8),
                                seasonal_order=(10, 1, 8, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4086     16.488     -0.025      0.980     -32.725      31.908
# ar.L2         -0.4350     51.109     -0.009      0.993    -100.608      99.737
# ar.L3         -0.1900     64.652     -0.003      0.998    -126.905     126.525
# ar.L4         -0.3753     19.339     -0.019      0.985     -38.280      37.529
# ar.L5          0.3739     47.876      0.008      0.994     -93.461      94.208
# ar.L6         -0.3398     43.967     -0.008      0.994     -86.513      85.834
# ar.L7         -0.4820     62.293     -0.008      0.994    -122.573     121.609
# ar.L8          0.1621    144.366      0.001      0.999    -282.790     283.114
# ar.L9          0.4892     72.448      0.007      0.995    -141.507     142.485
# ar.L10        -0.2884     37.233     -0.008      0.994     -73.263      72.686
# ma.L1         -0.2287     26.078     -0.009      0.993     -51.341      50.884
# ma.L2          0.0629     11.120      0.006      0.995     -21.732      21.858
# ma.L3         -0.0902     26.995     -0.003      0.997     -52.999      52.819
# ma.L4         -0.0559     23.256     -0.002      0.998     -45.636      45.525
# ma.L5         -0.1515     53.728     -0.003      0.998    -105.457     105.154
# ma.L6         -0.1306     47.625     -0.003      0.998     -93.473      93.212
# ma.L7          0.0174     36.372      0.000      1.000     -71.269      71.304
# ma.L8         -0.0321     73.070     -0.000      1.000    -143.247     143.183
# ar.S.L12      -0.1331     34.438     -0.004      0.997     -67.631      67.365
# ar.S.L24      -0.1324     26.833     -0.005      0.996     -52.724      52.459
# ar.S.L36       0.1275     31.247      0.004      0.997     -61.116      61.371
# ar.S.L48      -0.1413     78.803     -0.002      0.999    -154.593     154.310
# ar.S.L60       0.0905     29.014      0.003      0.998     -56.776      56.957
# ar.S.L72       0.2334     31.654      0.007      0.994     -61.808      62.275
# ar.S.L84       0.4128     29.483      0.014      0.989     -57.372      58.198
# ar.S.L96       0.2709     54.786      0.005      0.996    -107.108     107.650
# ar.S.L108     -0.1779     44.163     -0.004      0.997     -86.737      86.381
# ar.S.L120      0.4569     35.327      0.013      0.990     -68.783      69.696
# ma.S.L12       0.0415     22.727      0.002      0.999     -44.502      44.585
# ma.S.L24       0.0112     32.055      0.000      1.000     -62.815      62.837
# ma.S.L36       0.0044     45.220   9.78e-05      1.000     -88.626      88.634
# ma.S.L48      -0.0067     44.211     -0.000      1.000     -86.658      86.644
# ma.S.L60       0.0069     37.754      0.000      1.000     -73.990      74.004
# ma.S.L72      -0.0142     47.429     -0.000      1.000     -92.973      92.944
# ma.S.L84      -0.0224    109.236     -0.000      1.000    -214.121     214.076
# ma.S.L96       0.0005     43.729   1.12e-05      1.000     -85.706      85.707
# sigma2      1.328e+07      0.002    6.3e+09      0.000    1.33e+07    1.33e+07
# ==============================================================================

# %%
pred = results.get_prediction(start=datetime.datetime(2019,10,6), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2017':].plot(label='Serie Obsevada',color='yellow',lw = 4,figsize=(15,5))

pred.predicted_mean.plot(ax=ax, label='Prediccion', alpha=.7, color='magenta')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='red', alpha=.2)
plt.title("Predicción SARIMAX One-Step Último Trimestre-2019", color= 'blue', fontsize=25)
ax.set_xlabel('Fecha',color='red')
ax.set_ylabel('Cantidad de pasos',color='red')
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2019-10-06':]


rmse_so = np.sqrt(mean_squared_error(y_truth,y_forecasted ))
print(f'RMSE de SARIMAX One-Step es: {rmse_so }')
# Out:
# RMSE de SARIMAX One-Step es: 35.07039258010745

# %% [markdown]
# **La prediccion con SARIMAX tanto One-Step, como Multi-Step fueron muy buenas, los RSME que arrojan son excelentes. Por lo tanto SARIMAX One-Step fue el modelo elegido para predecir el 2020**

# %% [markdown]
# ### Año 2020

# %% [markdown]
# ##### Producir y visualizar pronósticos
# * Aprovechar nuestro modelo de serie temporal ARIMA estacional para pronosticar valores futuros. El get_forecast()atributo de nuestro objeto de serie temporal puede calcular valores pronosticados para un número específico de pasos adelante. Podemos usar la salida de este código para trazar la serie de tiempo y los pronósticos de sus valores futuros.

# %% [markdown]
# Una serie de tiempo es una secuencia de valores ordenados en el tiempo.
# Generalmente son mediciones de una misma variable, o sucesos que pasaron en un determinado momento del tiempo.
# Una de las funciones más buscadas a la hora de trabajar con series de tiempo es la posibilidad de predecir el futuro
# Por lo que estamos asumiendo un supuesto muy importante: **que el futuro se va a comportar como el pasado**. Es importante saber  que estamos presuponiendo esto a la hora de trabajar con predicciones en series de tiempo. El futuro es incierto y podemos aproximarnos a lo que puede llegar a suceder, ¡pero siempre vamos a tener un componente de sorpresa!
# **La pandemia y la cuarentena fue ese elemento sorpresa**, a esto se le suma la **obligación en el uso de Telepase**, por lo las predicciones hechas con los datos del 2017 al 2019 tienen sentido compararlas, desde mi punto de vista hasta marzo 2020, especìficamente hasta el 15/03/2020, si tomamos semanas completas. La obligatoriedad en el uso de Telepase, y las polìticas aplicadas (descuentos de hasta el 50%,agilidad en los pases si se usa Telepase,  única cabina para pago con efectivo,etc) es un claro indicador de que los usuarios migrarán hacia la forma de pago con Telepase (así lo hemos comprobado).
#
# A mi entender,  el comportamiento de los usuarios despues de marzo 2020, no será el mismo, la forma de pago con telepase será la forma habitual de pago, y me animo a predecir que será la adoptada en el resto del pais a medida que las Concesionarias de Peajes las vayan instrumentando como forma de pago.
# Dicho lo anterior, y para poder evaluar en forma objetiva el desempeño del Modelo elegido, se predecirá y evaluará hasta el 15/03/2020, siendo esta la ultima semana completa decretada el ASPO.

# %%
#graficando desde el 2017
pred_uc = results.get_forecast(steps=datetime.datetime(2020,3,15))
pred_ci = pred_uc.conf_int()

ax = y.plot(label='Cantidad_pasos', color='green',figsize=(15,5))
pred_uc.predicted_mean.plot(ax=ax, label='Predicciones 2020', color='magenta')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='red', alpha=.25)
plt.title("Predicción SARIMAX Año-2020", color= 'blue', fontsize=25)
ax.set_xlabel('Fecha', color='red')
ax.set_ylabel('Cantidad de pasos', color='red')

plt.legend()
plt.show()

# %%
#Graficando desde el último trimestre del 2019
pred_uc = results.get_forecast(steps=datetime.datetime(2020,3,15))
pred_ci = pred_uc.conf_int()

ax = y.plot(label='Cantidad_pasos', color='green',figsize=(15,5))
pred_uc.predicted_mean.plot(ax=ax, label='Predicciones 2020', color='magenta')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='red', alpha=.25)
plt.title("Predicción SARIMAX Año-2020", color= 'blue', fontsize=25)
plt.xlim(datetime.datetime(2019,10,6), datetime.datetime(2020,3,15))
ax.set_xlabel('Fecha', color='red')
ax.set_ylabel('Cantidad de pasos', color='red')

plt.legend()
plt.show()

# %% [markdown]
# *Las interrupciones en el gráfico que se observan se debe a que se tomans semanas enteras, la ultima semana del año 2019 y la primera del año 2020 son semnas cortadas

# %% [markdown]
# ## Modelo Benchmark

# %% [markdown]
# *Nuestro Modelo Benchmark es la prediccion que hizo Sarimax hasta el 15/03/2020

# %%
# Prediccion Sarimax
y_s_2020=pred_uc.predicted_mean
# 1º trimestre 2020 del 05/01/2020 al 15/03/2020 antes que empiece la cuarentena. Datos AUSA
fecha_i='2020-01-05'
fecha_f='2020-03-15'
y_2020=semanal_2020_m[(semanal_2020_m.index >=fecha_i)&(semanal_2020_m.index <=fecha_f)]



b_rmse=np.sqrt(mean_squared_error(y_2020, y_s_2020))

# %%
print('---------------------------------')
print(f'RMSE en Benchmark: {b_rmse}')
print('---------------------------------')

plt.figure(figsize=(15,5))
plt.plot(y_2020.index, y_2020.cantidad_pasos,color='green', label='Primer Trimestre 2020(Datos AUSA)')
plt.plot(y_s_2020.index, y_s_2020, lw=3, color='magenta',label='Prediccion del primer trimestre 2020(SARIMAX))')
plt.title ('Benchmark\n', color='red', fontsize=30)
plt.xlabel('\n Fecha', color='blue',fontsize=14)
plt.ylabel('Cantidad de pasos', color='blue',fontsize=14)

plt.legend(fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------
# RMSE en Benchmark: 8196.343330877053
# ---------------------------------

# %% [markdown]
# * Podemos Observar que la Prediccion de Sarimax para el primer trimestre 2020, no es tan buena como la que realizó para el último Trimestre 2019. Capaz se debió a que la migraciòn a Telepase fue mas rápida de lo que se predecía, dados los beneficios que esta forma de pago ofrecía (descuento y rapidez)
#
# * Probaremos un nuevo Modelo de ML: Prophet y confrontaremos los resultados

# %% [markdown]
# ## Prophet:
#
# *Modelo de ML nuevo*

# %% [markdown]
# **Prophet es un software de código abierto lanzado por el equipo Core Data Science de Facebook**
#
# Prophet es un procedimiento para pronosticar datos de series de tiempo basado en un modelo aditivo donde las tendencias no lineales se ajustan a la estacionalidad anual, semanal y diaria, más los efectos de las vacaciones. Funciona mejor con series de tiempo que tienen fuertes efectos estacionales y varias temporadas de datos históricos. Prophet es robusto ante los datos faltantes y los cambios de tendencia, y normalmente maneja bien los valores atípicos.

# %%
import pandas as pd
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# Condición para trabajar con Prophet: La entrada a Prophet es siempre un marco de datos con dos columnas: ds e y. La ds columna (marca de fecha) debe tener el formato esperado por Pandas, idealmente AAAA-MM-DD para una fecha o AAAA-MM-DD HH: MM: SS para una marca de tiempo. La y columna debe ser numérica y representa la medida que deseamos pronosticar. Por esta razón renombramos las columnas

# %%
semanal_m_1 = semanal_m.copy()
semanal_m_1.reset_index(level=0, inplace=True)
semanal_m_1= semanal_m_1.rename(columns={'fecha': 'ds',
                        'cantidad_pasos': 'y'})
semanal_m_1.head()
# Out:
#           ds             y
# 0 2017-01-08  49601.714286
# 1 2017-01-15  52344.714286
# 2 2017-01-22  51030.714286
# 3 2017-01-29  50654.428571
# 4 2017-02-05  51343.000000

# %%
semanal_m_1.tail()
# Out:
#             ds             y
# 151 2019-12-01  38079.285714
# 152 2019-12-08  40413.000000
# 153 2019-12-15  38994.285714
# 154 2019-12-22  41840.142857
# 155 2019-12-29  32341.428571

# %%
ax = semanal_m_1.set_index('ds').plot(figsize=(12, 8))
plt.title("Flujo de pasos por semana", color= 'red', fontsize= 20)
ax.set_ylabel('Cantidad de pasos',color='blue',fontsize= 15 )
ax.set_xlabel('Fecha',color='blue',fontsize= 15 )

plt.show()

# %%
prophet_model = Prophet(interval_width= 0.95 )
prophet_model.fit(semanal_m_1)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# * Creo el DF partir del modelo entrenado con la cantidad total de fechas a predecir: hasta el 15/03/2020: 11 semanas (Ya que la frecuencia  es semanal).

# %%
future_dates = prophet_model.make_future_dataframe(periods=11, freq='W')
future_dates.head()
# Out:
#           ds
# 0 2017-01-08
# 1 2017-01-15
# 2 2017-01-22
# 3 2017-01-29
# 4 2017-02-05

# %%
future_dates = prophet_model.make_future_dataframe(periods=11, freq='W')
future_dates.tail()
# Out:
#             ds
# 162 2020-02-16
# 163 2020-02-23
# 164 2020-03-01
# 165 2020-03-08
# 166 2020-03-15

# %% [markdown]
# El Modelo asignará a cada fila future un valor predicho que nombra yhat.

# %%
forecast = prophet_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
#           ds          yhat    yhat_lower    yhat_upper
# 0 2017-01-08  45869.440056  41643.556079  50360.700344
# 1 2017-01-15  46825.862635  42173.733254  51597.487391
# 2 2017-01-22  48711.686193  43836.820334  53295.394540
# 3 2017-01-29  50016.177287  46042.180047  54660.795334
# 4 2017-02-05  50108.100251  45698.348626  54502.875872

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 162 2020-02-16  35978.632669  31175.185485  40250.539474
# 163 2020-02-23  35623.267505  30598.945261  40055.125375
# 164 2020-03-01  35787.641475  31533.613928  40236.275793
# 165 2020-03-08  36170.317340  31791.483033  40844.684150
# 166 2020-03-15  36419.670037  31722.284159  40978.878209

# %% [markdown]
# Los valores predichos(yhat) por el modelo para las fechas observadas(ds) de los años trabajados

# %%
fig1 = prophet_model.plot(forecast)
plt.title("Predicción de Prophet\n", color= 'red', fontsize=25)
plt.xlabel('\n Fecha', fontsize=15, color='blue')
plt.ylabel('Cantidad de pasos', loc= 'top', fontsize=15,color='blue')
plt.show()

# %% [markdown]
# *Los puntos negros que indican los puntos de datos utilizados para entrenar el modelo.*
#
# *La línea traza la predicción.*
#
# *La función traza los intervalos de incertidumbre..*

# %% [markdown]
# ## Contrastando los Modelos con la Serie Observada (AUSA)

# %% [markdown]
# ### Año 2019

# %%
prophet_2019_p = forecast[(forecast.ds >= "2019-10-06") & (forecast.ds <= "2019-12-29")]
prophet_2019_p.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)
prophet_2019_p.rename(columns={'ds':'fecha', "yhat":'cantidad_pasos'}, inplace=True)
prophet_2019_p = prophet_2019_p.set_index('fecha')
prophet_2019_p
# Out:
#             cantidad_pasos
# fecha
# 2019-10-06    38618.255863
# 2019-10-13    38069.257780
# 2019-10-20    38357.785862
# 2019-10-27    39453.124543
# 2019-11-03    40350.629731
# 2019-11-10    40126.992217
# 2019-11-17    39040.782952
# 2019-11-24    38345.139707
# 2019-12-01    38890.999206
# 2019-12-08    40042.087541
# 2019-12-15    40183.801338
# 2019-12-22    38379.703806
# 2019-12-29    35439.338668

# %%
y_o_2019=semanal_m[(semanal_m.index >='2019-10-06')&(semanal_m.index <='2019-12-29')]
y_o_2019
# Out:
#             cantidad_pasos
# fecha
# 2019-10-06    38926.142857
# 2019-10-13    37262.857143
# 2019-10-20    38163.857143
# 2019-10-27    37564.285714
# 2019-11-03    39018.428571
# 2019-11-10    38648.000000
# 2019-11-17    40255.714286
# 2019-11-24    37785.714286
# 2019-12-01    38079.285714
# 2019-12-08    40413.000000
# 2019-12-15    38994.285714
# 2019-12-22    41840.142857
# 2019-12-29    32341.428571

# %%
pred = results.get_prediction(start=datetime.datetime(2019,10,6), dynamic=False)
sarimax_2019_p= pred.predicted_mean
sarimax_2019_p = pd.DataFrame(sarimax_2019_p)

sarimax_2019_p.rename(columns={"predicted_mean":'cantidad_pasos'}, inplace=True)


sarimax_2019_p = sarimax_2019_p.set_index(sarimax_2019_p.index)

sarimax_2019_p
# Out:
#             cantidad_pasos
# fecha
# 2019-10-06    38984.337267
# 2019-10-13    37197.291817
# 2019-10-20    38170.553441
# 2019-10-27    37557.002148
# 2019-11-03    39006.959003
# 2019-11-10    38650.348262
# 2019-11-17    40290.121472
# 2019-11-24    37810.131444
# 2019-12-01    38098.677586
# 2019-12-08    40453.237466
# 2019-12-15    39039.893439
# 2019-12-22    41883.838538
# 2019-12-29    32323.986186

# %%
plt.figure(figsize=(15,5))

plt.plot(y_o_2019.index, y_o_2019.cantidad_pasos,color='yellow', label='Serie Observada último trimestre 2019(Datos AUSA)')
plt.plot(sarimax_2019_p.index, sarimax_2019_p.cantidad_pasos,'-.',lw=2, color='magenta',label='SARIMAX Predicción del último trimestre 2019')
plt.plot(prophet_2019_p.index, prophet_2019_p.cantidad_pasos, lw=3, color='green',label='Prophet Predicción del último trimestre 2019')

plt.title ('Año 2019:  Observada vs Sarimax vs Prophet', color='red', fontsize=30)
plt.xlabel('\n Fecha', color='blue',fontsize=14)
plt.ylabel('Cantidad de pasos', color='blue',fontsize=14)

plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

y_p_pro=  prophet_2019_p.cantidad_pasos
y= y_o_2019.cantidad_pasos
rmse_pro = np.sqrt(mean_squared_error(y,y_p_pro))

print(f'RMSE de PROPHET  es: {rmse_pro }')
print(f'RMSE de SARIMAX One-Step es: {rmse_so }')
# Out:
# RMSE de PROPHET  es: 1614.470081347105
# RMSE de SARIMAX One-Step es: 35.07039258010745

# %% [markdown]
# **La prediccioón con SARIMAX One-Step para el ültimo Trimestre del 2019 es realmente insuperable**

# %% [markdown]
# ### Año 2020

# %%
prophet_2020_p =forecast[(forecast.ds >= "2020-01-05") & (forecast.ds <= "2020-03-15")]
prophet_2020_p.drop(columns=["trend", "yhat_lower", "yhat_upper",
                       "trend_lower", "trend_upper", "additive_terms",
                       "additive_terms_lower", "additive_terms_upper",
                       "yearly", "yearly_lower", "yearly_upper", 
                       "multiplicative_terms", "multiplicative_terms_lower", 
                       "multiplicative_terms_upper"], inplace= True)
prophet_2020_p.rename(columns={'ds':'fecha', "yhat":'cantidad_pasos'}, inplace=True)
prophet_2020_p = prophet_2020_p.set_index('fecha')
prophet_2020_p
# Out:
#             cantidad_pasos
# fecha
# 2020-01-05    33261.649649
# 2020-01-12    33131.418899
# 2020-01-19    34677.108133
# 2020-01-26    36406.411244
# 2020-02-02    37108.388407
# 2020-02-09    36711.777049
# 2020-02-16    35978.632669
# 2020-02-23    35623.267505
# 2020-03-01    35787.641475
# 2020-03-08    36170.317340
# 2020-03-15    36419.670037

# %%
# Prediccion Sarimax: Modelo Benchmark
y_s_2020=pred_uc.predicted_mean
# 1º trimestre 2020 del 05/01/2020 al 15/03/2020 antes que empiece la cuarentena. Datos AUSA
fecha_i='2020-01-05'
fecha_f='2020-03-15'
y_2020=semanal_2020_m[(semanal_2020_m.index >=fecha_i)&(semanal_2020_m.index <=fecha_f)]
plt.figure(figsize=(15,5))

plt.plot(y_2020.index, y_2020.cantidad_pasos,color='yellow',lw=3, label='Serie Observada Primer trimestre 2020(Datos AUSA)')
plt.plot(y_s_2020.index, y_s_2020, lw=3, color='magenta',label='Prediccion del primer trimestre 2020(SARIMAX))')
plt.plot(prophet_2020_p.index, prophet_2020_p.cantidad_pasos,lw=3 , color='green',label='Prophet Predicción del Primer trimestre 2020')

plt.title ('Año 2020:  Observada vs Sarimax vs Prophet', color='red', fontsize=30)
plt.xlabel('\n Fecha', color='blue',fontsize=14)
plt.ylabel('Cantidad de pasos', color='blue',fontsize=14)

plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

y_pro_p=  prophet_2020_p.cantidad_pasos
y= y_2020.cantidad_pasos
rmse_pro_20 = np.sqrt(mean_squared_error(y,y_pro_p))

print(f'RMSE de PROPHET  es: {rmse_pro_20 }')
print(f'RMSE en Benchmark (Sarimax One-Step): {b_rmse}')# Prediccion hecha con Sarimax
# Out:
# RMSE de PROPHET  es: 2096.1452952432674
# RMSE en Benchmark (Sarimax One-Step): 8196.343330877053

# %% [markdown]
# **El Modelo Prophet es el mejor modelo de ML que predijo el 2020**, ya que es su valor de RMSE es la cuarta parte del Benchmark, que en este caso es la predicción que se hizo con Sarimax One-Step.
#
# Capaz se debe a que Prophet es resistente a valores atípicos, datos faltantes y cambios drásticos en su serie temporal.

# %% [markdown]
# ## Conclusiones Finales

# %% [markdown]
# Este Proyecto requeririó la implementación de un nuevo Modelo de ML que no fue visto en clase, por lo que tuvimos el desafío de investigar, consultar y probar hasta lograr un resultado . Entiendo que fue como el último gran aprendizaje de ACAMICA para un DS, siempre nos encontraremos con cosas nuevas que podremos probar e implementar.
#
# Con respecto al resultado obtenido, no esperé nunca poder mejorar los resultados del Proyecto 3, con SARIMAX, bueno una vez más he aprendido que todo se puede mejorar, y que no podemos quedarnos en la zona de confort, creyendo que ya está todo hecho. Como dije en mi anterior conclusion el futuro es incierto y podemos aproximarnos a lo que puede llegar a suceder, ¡pero siempre vamos a tener un componente de sorpresa!. El gran desafío es aproximarnos los más posible al futuro .
#
# Me queda como desafío seguir estudiando y practicando. CApaz aun puedo mejorar más estas predicciones

# %% [markdown]
# ## Solicitud

# %% [markdown]
# **Estaría excelente un curso de DS 2 en ACÁMICA**
